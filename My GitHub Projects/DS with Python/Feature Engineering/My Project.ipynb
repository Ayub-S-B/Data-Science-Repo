# %%
import pandas as pd

# %% [markdown]
# # 1) Understand the dataset:

# %%
pd.read_csv('PEP1.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
PEP=pd.read_csv('PEP1.csv')

# %% [markdown]
# ## 1(a) Identify the shape of the dataset

# %%
PEP.shape
# Out:
# (1460, 81)

# %%
len(PEP)
# Out:
# 1460

# %% [markdown]
# ## 1(b) Identify variables with null values

# %%
PEP.isnull().sum().head(40)
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
# Alley           1369
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# dtype: int64

# %%
PEP.isnull().sum().tail(41)
# Out:
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchebvGr          0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functiol            0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %% [markdown]
# ## 1(c) Identify variables with unique values

# %%
PEP.nunique().head(40)
# Out:
# Id              1460
# MSSubClass        15
# MSZoning           5
# LotFrontage      110
# LotArea         1073
# Street             2
# Alley              2
# LotShape           4
# LandContour        4
# Utilities          2
# LotConfig          5
# LandSlope          3
# Neighborhood      25
# Condition1         9
# Condition2         8
# BldgType           5
# HouseStyle         8
# OverallQual       10
# OverallCond        9
# YearBuilt        112
# YearRemodAdd      61
# RoofStyle          6
# RoofMatl           8
# Exterior1st       15
# Exterior2nd       16
# MasVnrType         4
# MasVnrArea       327
# ExterQual          4
# ExterCond          5
# Foundation         6
# BsmtQual           4
# BsmtCond           4
# BsmtExposure       4
# BsmtFinType1       6
# BsmtFinSF1       637
# BsmtFinType2       6
# BsmtFinSF2       144
# BsmtUnfSF        780
# TotalBsmtSF      721
# Heating            6
# dtype: int64

# %%
PEP.nunique().tail(41)
# Out:
# HeatingQC          5
# CentralAir         2
# Electrical         5
# 1stFlrSF         753
# 2ndFlrSF         417
# LowQualFinSF      24
# GrLivArea        861
# BsmtFullBath       4
# BsmtHalfBath       3
# FullBath           4
# HalfBath           3
# BedroomAbvGr       8
# KitchebvGr         4
# KitchenQual        4
# TotRmsAbvGrd      12
# Functiol           7
# Fireplaces         4
# FireplaceQu        5
# GarageType         6
# GarageYrBlt       97
# GarageFinish       3
# GarageCars         5
# GarageArea       441
# GarageQual         5
# GarageCond         5
# PavedDrive         3
# WoodDeckSF       274
# OpenPorchSF      202
# EnclosedPorch    120
# 3SsnPorch         20
# ScreenPorch       76
# PoolArea           8
# PoolQC             3
# Fence              4
# MiscFeature        4
# MiscVal           21
# MoSold            12
# YrSold             5
# SaleType           9
# SaleCondition      6
# SalePrice        663
# dtype: int64

# %% [markdown]
# # 2) Generate a separate dataset for numerical and categorical variables

# %%
categorical_data=PEP.select_dtypes(include='object')
print(categorical_data)
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
categorical_data.shape[1]
# Out:
# 43

# %%
numeric_data = PEP.select_dtypes(exclude='object')
print(numeric_data)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
numeric_data.shape[1]
# Out:
# 38

# %% [markdown]
# # 3) EDA of numerical variables

# %% [markdown]
# ## 3(a) MISSING VALUE TREATMENT FOR NUMERICAL VARIABLES

# %%
numeric_data.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchebvGr         0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
numeric_data.isna().sum()[numeric_data.isna().sum()>0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
numeric_data.isna().sum()[numeric_data.isna().sum()>0].shape
# Out:
# (3,)

# %%
# Percentage of missing values in each numerical variable

# %%
percentage=(numeric_data.isna().sum()[numeric_data.isna().sum()>0]/1460)*100
print(percentage)
# Out:
# LotFrontage    17.739726
# MasVnrArea      0.547945
# GarageYrBlt     5.547945
# dtype: float64

# %%
# Removing the numerical variables having maximum missing values

# %%
No_miss_val = numeric_data.drop(['LotFrontage'],axis=1)
print(No_miss_val)
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# ...

# %%
# Percentage of missing values in each numerical variable after Removing the numerical variables having maximum missing values

# %%
No_miss_val.isna().sum()[No_miss_val.isna().sum()>0]/1460*100
# Out:
# MasVnrArea     0.547945
# GarageYrBlt    5.547945
# dtype: float64

# %%
# Missing Value imputation

# %%
PEP.loc[PEP.MasVnrArea.isna(),'MasVnrArea']
# Out:
# 234    NaN
# 529    NaN
# 650    NaN
# 936    NaN
# 973    NaN
# 977    NaN
# 1243   NaN
# 1278   NaN
# Name: MasVnrArea, dtype: float64

# %%
PEP.MasVnrArea.median()
# Out:
# 0.0

# %%
data_imput_1 = PEP.fillna(PEP.MasVnrArea.median())

# %%
data_imput_1.loc[PEP.MasVnrArea.isna(),'MasVnrArea']
# Out:
# 234     0.0
# 529     0.0
# 650     0.0
# 936     0.0
# 973     0.0
# 977     0.0
# 1243    0.0
# 1278    0.0
# Name: MasVnrArea, dtype: float64

# %%
PEP.loc[PEP.GarageYrBlt.isna(),'GarageYrBlt']
# Out:
# 39     NaN
# 48     NaN
# 78     NaN
# 88     NaN
# 89     NaN
#         ..
# 1349   NaN
# 1407   NaN
# 1449   NaN
# 1450   NaN
# 1453   NaN
# Name: GarageYrBlt, Length: 81, dtype: float64

# %%
PEP.loc[PEP.GarageYrBlt.isna(),'GarageYrBlt'].shape
# Out:
# (81,)

# %%
PEP.GarageYrBlt.median()
# Out:
# 1980.0

# %%
data_imput_2 = PEP.fillna(PEP.GarageYrBlt.median())

# %%
data_imput_2.loc[PEP.GarageYrBlt.isna(),'GarageYrBlt']
# Out:
# 39      1980.0
# 48      1980.0
# 78      1980.0
# 88      1980.0
# 89      1980.0
#          ...
# 1349    1980.0
# 1407    1980.0
# 1449    1980.0
# 1450    1980.0
# 1453    1980.0
# Name: GarageYrBlt, Length: 81, dtype: float64

# %% [markdown]
# ## 3(b) Identify the skewness and distribution

# %%
# Skewness and distribution before missing value data imputation

# %%
PEP.MasVnrArea.skew()
# Out:
# 2.669084210182863

# %%
PEP.MasVnrArea.hist()
# Out:
# <AxesSubplot:>

# %%
# Skewness and distribution after missing value data imputation

# %%
data_imput_1.MasVnrArea.skew()
# Out:
# 2.6776164510820997

# %%
data_imput_1.MasVnrArea.hist()
# Out:
# <AxesSubplot:>

# %%
# Skewness and distribution before missing value data imputation

# %%
PEP.GarageYrBlt.skew()
# Out:
# -0.6494146238714679

# %%
PEP.GarageYrBlt.hist()
# Out:
# <AxesSubplot:>

# %%
# Skewness and distribution after missing value data imputation

# %%
data_imput_2.GarageYrBlt.skew()
# Out:
# -0.6783329490955604

# %%
data_imput_2.GarageYrBlt.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3(C) Identify significant variables using a correlation matrix

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
numeric_data.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
for col in numeric_data.dtypes[numeric_data.dtypes != 'object'].index:
    
    print('No of unique values in ',col,numeric_data[col].nunique())
# Out:
# No of unique values in  Id 1460
# No of unique values in  MSSubClass 15
# No of unique values in  LotFrontage 110
# No of unique values in  LotArea 1073
# No of unique values in  OverallQual 10
# No of unique values in  OverallCond 9
# No of unique values in  YearBuilt 112
# No of unique values in  YearRemodAdd 61
# No of unique values in  MasVnrArea 327
# No of unique values in  BsmtFinSF1 637
# No of unique values in  BsmtFinSF2 144
# No of unique values in  BsmtUnfSF 780
# No of unique values in  TotalBsmtSF 721
# No of unique values in  1stFlrSF 753
# No of unique values in  2ndFlrSF 417
# No of unique values in  LowQualFinSF 24
# No of unique values in  GrLivArea 861
# No of unique values in  BsmtFullBath 4
# No of unique values in  BsmtHalfBath 3
# No of unique values in  FullBath 4
# No of unique values in  HalfBath 3
# No of unique values in  BedroomAbvGr 8
# No of unique values in  KitchebvGr 4
# No of unique values in  TotRmsAbvGrd 12
# No of unique values in  Fireplaces 4
# ...

# %%
## Since for Heatmap we want to consider only the continuos variables(having unique values >100), 
# we leave the variables which we consider as discrete variables(having unique values <100).

plt.figure(figsize=(15,15))
sns.heatmap(numeric_data[['LotFrontage','LotArea','YearBuilt','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF'
                          ,'2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','SalePrice']].corr(),
            annot=True,cmap='Blues',linecolor='white',linewidths=2)
plt.show()

# %% [markdown]
# ## 3(d) Pair plot for distribution and density

# %%
## Selecting only the most continous type of variables(variables having unique values >150) which we consider as 'significant variables'
## for Pair plot to be more clear and understandable.

plt.figure(figsize=(7,7))
sns.pairplot(numeric_data[['LotArea','MasVnrArea','BsmtFinSF1','BsmtUnfSF','TotalBsmtSF','1stFlrSF'
                          ,'2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','SalePrice']])
plt.show()

# %%
significant_numeric_data = (numeric_data[['LotArea','MasVnrArea','BsmtFinSF1','BsmtUnfSF','TotalBsmtSF','1stFlrSF'
                          ,'2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','SalePrice']])

# %% [markdown]
# # 4) EDA of categorical variables

# %% [markdown]
# ## 4(a) Missing value treatment

# %%
categorical_data.isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functiol            0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
categorical_data.isna().sum()[categorical_data.isna().sum()>0]
# Out:
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
categorical_data.isna().sum()[categorical_data.isna().sum()>0].shape
# Out:
# (16,)

# %%
## Percentage of missing values in each categorical variable

# %%
percentage = (categorical_data.isna().sum()[categorical_data.isna().sum()>0]/1460)*100
print(percentage)
# Out:
# Alley           93.767123
# MasVnrType       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
## Removing the categorical variables having maximum missing values

# %%
No_miss_val = categorical_data.drop(['Alley','FireplaceQu','PoolQC','Fence','MiscFeature'],axis=1)
print(No_miss_val)
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual Functiol  \
# ...

# %%
## Percentage of missing values in each categorical variable after Removing the categorical variables having maximum missing values

# %%
after_drop = No_miss_val.isna().sum()[No_miss_val.isna().sum()>0]/1460*100
print(after_drop)
# Out:
# MasVnrType      0.547945
# BsmtQual        2.534247
# BsmtCond        2.534247
# BsmtExposure    2.602740
# BsmtFinType1    2.534247
# BsmtFinType2    2.602740
# Electrical      0.068493
# GarageType      5.547945
# GarageFinish    5.547945
# GarageQual      5.547945
# GarageCond      5.547945
# dtype: float64

# %%
after_drop.shape
# Out:
# (11,)

# %%
## Missing Value imputation

# %%
## (1)

# %%
categorical_data['MasVnrType'].mode()
# Out:
# 0    None
# Name: MasVnrType, dtype: object

# %%
categorical_data['MasVnrType'].fillna('None', inplace = True)

# %%
categorical_data['MasVnrType'].isna().sum()
# Out:
# 0

# %%
## (2)

# %%
categorical_data['BsmtQual'].isna().sum()
# Out:
# 37

# %%
categorical_data['BsmtQual'].mode()
# Out:
# 0    TA
# Name: BsmtQual, dtype: object

# %%
categorical_data['BsmtQual'].fillna('None', inplace = True)

# %%
categorical_data['BsmtQual'].isna().sum()
# Out:
# 0

# %%
## (3)

# %%
categorical_data['BsmtCond'].isna().sum()
# Out:
# 37

# %%
categorical_data['BsmtCond'].mode()
# Out:
# 0    TA
# Name: BsmtCond, dtype: object

# %%
categorical_data['BsmtCond'].fillna('None', inplace = True)

# %%
categorical_data['BsmtCond'].isna().sum()
# Out:
# 0

# %%
## (4)

# %%
categorical_data['BsmtExposure'].isna().sum()
# Out:
# 38

# %%
categorical_data['BsmtExposure'].mode()
# Out:
# 0    No
# Name: BsmtExposure, dtype: object

# %%
categorical_data['BsmtExposure'].fillna('None', inplace = True)

# %%
categorical_data['BsmtExposure'].isna().sum()
# Out:
# 0

# %%
## (5)

# %%
categorical_data['BsmtFinType1'].isna().sum()
# Out:
# 37

# %%
categorical_data['BsmtFinType1'].mode()
# Out:
# 0    Unf
# Name: BsmtFinType1, dtype: object

# %%
categorical_data['BsmtFinType1'].fillna('None', inplace = True)

# %%
categorical_data['BsmtFinType1'].isna().sum()
# Out:
# 0

# %%
## (6)

# %%
categorical_data['BsmtFinType2'].isna().sum()
# Out:
# 38

# %%
categorical_data['BsmtFinType2'].mode()
# Out:
# 0    Unf
# Name: BsmtFinType2, dtype: object

# %%
categorical_data['BsmtFinType2'].fillna('None', inplace = True)

# %%
categorical_data['BsmtFinType2'].isna().sum()
# Out:
# 0

# %%
## (7)

# %%
categorical_data['Electrical'].isna().sum()
# Out:
# 1

# %%
categorical_data['Electrical'].mode()
# Out:
# 0    SBrkr
# Name: Electrical, dtype: object

# %%
categorical_data['Electrical'].fillna('None', inplace = True)

# %%
categorical_data['Electrical'].isna().sum()
# Out:
# 0

# %%
## (8)

# %%
categorical_data['GarageType'].isna().sum()
# Out:
# 81

# %%
categorical_data['GarageType'].mode()
# Out:
# 0    Attchd
# Name: GarageType, dtype: object

# %%
categorical_data['GarageType'].fillna('None', inplace = True)

# %%
categorical_data['GarageType'].isna().sum()
# Out:
# 0

# %%
## (9)

# %%
categorical_data['GarageFinish'].isna().sum()
# Out:
# 81

# %%
categorical_data['GarageFinish'].mode()
# Out:
# 0    Unf
# Name: GarageFinish, dtype: object

# %%
categorical_data['GarageFinish'].fillna('None', inplace = True)

# %%
categorical_data['GarageFinish'].isna().sum()
# Out:
# 0

# %%
## (10)

# %%
categorical_data['GarageQual'].isna().sum()
# Out:
# 81

# %%
categorical_data['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
categorical_data['GarageQual'].fillna('None', inplace = True)

# %%
categorical_data['GarageQual'].isna().sum()
# Out:
# 0

# %%
## (11)

# %%
categorical_data['GarageCond'].isna().sum()
# Out:
# 81

# %%
categorical_data['GarageCond'].mode()
# Out:
# 0    TA
# Name: GarageCond, dtype: object

# %%
categorical_data['GarageCond'].fillna('None', inplace = True)

# %%
categorical_data['GarageCond'].isna().sum()
# Out:
# 0

# %%
# 'significant categorical variables' after dropping the maximum missing value variables (as done before)

significant_categoric_data = categorical_data.drop(['Alley','FireplaceQu','PoolQC','Fence','MiscFeature'],axis=1)

# %%
significant_categoric_data
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual Functiol  \
# ...

# %% [markdown]
# ## 4(b) Count plot and box plot for bivariate analysis

# %%
sns.countplot('SaleCondition',data=categorical_data)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='count'>

# %%
## Box plot for bivariate analysis.

sns.boxplot('SaleCondition','SalePrice', data = PEP)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %% [markdown]
# # 5) Combine all the significant categorical and numerical variables

# %%
significant_categoric_data
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual Functiol  \
# ...

# %%
significant_numeric_data
# Out:
#       LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0        8450       196.0         706        150          856       856
# 1        9600         0.0         978        284         1262      1262
# 2       11250       162.0         486        434          920       920
# 3        9550         0.0         216        540          756       961
# 4       14260       350.0         655        490         1145      1145
# ...       ...         ...         ...        ...          ...       ...
# 1455     7917         0.0           0        953          953       953
# 1456    13175       119.0         790        589         1542      2073
# 1457     9042         0.0         275        877         1152      1188
# 1458     9717         0.0          49          0         1078      1078
# 1459     9937         0.0         830        136         1256      1256
#
#       2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  OpenPorchSF  SalePrice
# ...

# %%
df1 = significant_categoric_data

# %%
df2 = significant_numeric_data

# %% [markdown]
# # 6)Plot box plot for the new dataset to find the variables with outliers

# %%
plt.figure(figsize=(15,10))
sns.boxplot( data = df2)
# Out:
# <AxesSubplot:>
